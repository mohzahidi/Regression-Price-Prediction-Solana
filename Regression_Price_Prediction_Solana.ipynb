# %% [markdown]
# <a href="https://colab.research.google.com/github/mohzahidi/Regression-Price-Prediction-Solana/blob/main/Regression_Price_Prediction_Solana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd

# %%
ticker_symbol = 'SOL-USD'
start_date = '2021-01-01'
end_date = '2025-09-05'

solana_data = yf.download(ticker_symbol, start=start_date, end=end_date)
# Out:
# /tmp/ipython-input-309010108.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   solana_data = yf.download(ticker_symbol, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
print(solana_data.head())
# Out:
# Price          Close      High       Low      Open    Volume
# Ticker       SOL-USD   SOL-USD   SOL-USD   SOL-USD   SOL-USD
# Date
# 2021-01-01  1.842084  1.859656  1.502038  1.509775  25722549
# 2021-01-02  1.799275  1.989295  1.721482  1.845586  31671064
# 2021-01-03  2.161752  2.364981  1.799902  1.799902  55073422
# 2021-01-04  2.485097  2.485097  1.876342  2.162412  59955405
# 2021-01-05  2.157217  2.502616  2.077742  2.490982  50555207

# %%
solana_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1708 entries, 2021-01-01 to 2025-09-04
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Close, SOL-USD)   1708 non-null   float64
#  1   (High, SOL-USD)    1708 non-null   float64
#  2   (Low, SOL-USD)     1708 non-null   float64
#  3   (Open, SOL-USD)    1708 non-null   float64
#  4   (Volume, SOL-USD)  1708 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 80.1 KB

# %%
solana_data.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker      SOL-USD      SOL-USD      SOL-USD      SOL-USD       SOL-USD
# count   1708.000000  1708.000000  1708.000000  1708.000000  1.708000e+03
# mean      93.391001    96.891093    89.761871    93.291338  2.337855e+09
# std       70.320803    72.734366    67.825856    70.330744  2.525500e+09
# min        1.799275     1.859656     1.502038     1.509775  2.572255e+07
# 25%       24.984305    25.949749    24.225914    24.979028  5.551852e+08
# 50%       87.995304    91.742390    84.411285    87.864361  1.710930e+09
# 75%      152.484718   157.772541   146.898613   152.409042  3.217201e+09
# max      261.869751   294.334961   253.187439   261.872437  3.317296e+10
